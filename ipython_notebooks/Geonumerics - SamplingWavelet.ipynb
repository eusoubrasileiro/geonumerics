# %%
# %cd home
import Filters
import WaveFd
# Out:
# (bookmark:home) -> /home/andre/Documents/DevPython/geonumerics/source/python
# /home/andre/Documents/DevPython/geonumerics/source/python

# %%
ricker = WaveFd.Ricker(40, 0.001)
plot(ricker)
figure()
Filters.PlotFftAbs(ricker, 0.001)
axis(xmin=0, xmax=200)
# Out:
# (0, 200, 0.0, 12.0)

# %%
T=1.0/40.0

# %%
T/0.001
# Out:
# 25.0
