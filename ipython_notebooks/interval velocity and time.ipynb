# %% [markdown]
# ### Layer cake velocity model tests ###

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from matplotlib import pylab
import numpy as np

# %% [markdown]
# Testing times computed from:
#
# * Constant velocity (mean) 1491 m/s
#
# * Linear interval velocity function in water layer
#     $$ V_i(z) = V_0 + (z-z_0) k $$
#   with velocity gradient 0.008 m/s per meter (google)
#     $$ V_i(z) = 1480 + z*0.008 $$

# %%
ax = pylab.subplot(111)
ax.plot(1480.+numpy.arange(0, 3000)*0.008)
ax.plot(1491.+numpy.zeros(3000))
pylab.show()

# %% [markdown]
# **After integrating interval velocity functions to create time function**
#
# $$t(z) = z/v_0$$
#
# $$t(z) = \frac{1}{k}*\ln{\frac{|{kz+v_0-kz_0}|}{|v_0-kz_0|}} +t_0$$

# %%
ax = pylab.subplot(111)
z = numpy.arange(0, 3000)
tz_average=z/1491.
ax.plot(tz_average)
tz_integrated_linear = (1./0.008)*np.log(np.abs(0.008*z+1480)/(np.abs(1480)))
ax.plot(tz)
pylab.show()

# %%
ax = pylab.subplot(111)
ax.plot(np.abs(tz_average-tz_integrated_linear)*1000)
pylab.ylabel('time difference (ms)')
