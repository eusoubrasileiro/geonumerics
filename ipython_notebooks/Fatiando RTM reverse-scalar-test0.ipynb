# %% [markdown]
# ##This is a test experiment for knowing if my reverse in time scalar implementation is working##
#
# So beware that the zero-offsection hereby presented in the consequent "migration" is not
# expected to have a reasonably decency

# %%
# %cd fatiando
# %cd ..
# Out:
# (bookmark:fatiando) -> /home/andre/PycharmProjects/fatiando
# /home/andre/PycharmProjects/fatiando
# /home/andre/PycharmProjects

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from PIL import Image
import numpy as np
img = Image.open('wedge.tif')
img.load()
img = img.convert('I') # gray scale, convert format
data  = np.asarray(img, dtype=np.float32)
data[:][data[:] == 255.] = 2500.0 # overburden
data[:][data[:] == 0. ] = 3500 # the triangle
data[:][data[:] == 146.] = 2300.0 # the first slab bellow the triangle
data[:][data[:] == 36.] = 2700.0 # the last slab
cshape = data.shape
print cshape
imshow(data)
# Out:
# (160, 400)

# %% [markdown]
# ###Loading back the results of the previous simulation###
#
# We gonna create the pseudosection and rtm migrate it

# %%
# %cd /home/andre/PycharmProjects/fatiando
import numpy as np
shots = np.load('arrayshots_70.npy')
print shots.shape
# Out:
# /home/andre/PycharmProjects/fatiando
# (100, 917, 70)

# %%
zeroffset = np.zeros((500, 100))
for i in range(100):
    zeroffset[:,i] =  shots[i][:500, 35]
    
zeroffset[:170, :] = 0.0
figure(figsize=(10, 15))
imshow(zeroffset, aspect=0.12, origin='upper', cmap=mpl.cm.gray_r, vmin=-.1, vmax=.1)

# %% [markdown]
# ### Lets try to smooth it a bit, removing numerical dispersion ###
#
# I might need to remove direct waves and refractions too...
#
# Nyquest rate from simulation dt is
#
# Fn = 1/(2*0.00435758283082879) = 114.74251194093827
#
# Then filtering to the source frequency **fc = 23.0** would be:
#
# Flowpass = 0.20044881021812433 for charity ~ 0.21

# %%
#Now create a lowpass Butterworth to lowpass the source frequency
from scipy import signal
#b, a = signal.butter(8, 0.5)
#zeroffset = signal.filtfilt(b, a, zeroffset)

fir = signal.firwin(527, 0.25)

for i in xrange(100):
    zeroffset[:, i] = signal.convolve(zeroffset[:, i], fir, 'same') # first must be the larger array

figure(figsize=(10,15))
imshow(zeroffset, aspect=0.12, origin='upper', cmap=mpl.cm.gray_r, vmin=-.1, vmax=.1)

# %% [raw]
# Getting the previous parameters for source and dt
# The dt will be good since it was enough for the previous
#
# dt = 3.99590345587/917 = 0.00435758283082879
# fc = 23.0
#
# Dsource = 100.0
# Dstations = 100.0
#
# Starting shotting at x=5000
# Shotting 100 shots
#
# 70 stations
# 30 fold
#
# 3500 max offset each side
#
# first station positive positon at 5000+3550
#
# The expression bellow gets the coordinates of the pseudo-zeroffset traces.

# %%
xcmp = [ 5000+i*100+3550 for i in xrange(100)]

# %% [raw]
# Now lets convert it back to the index positons of the velocity model

# %%
imp = [ 10+i*2+71 for i in xrange(100)]

# %% [raw]
# Now get just those positions of the velocity model to create the depth velocity model for migration

# %%
vmig = data[:120, imp]
vshape = vmig.shape
print vshape
figure(figsize=(10,15))
imshow(vmig, extent=[xcmp[0], xcmp[::-1][0], 0., 25*100])
# Out:
# (120, 100)

# %%
# Basic parameters for zero-offset reverse modeling
dx = 100. # spacing between ~ pseudo cmps
dz = 25. # still the same from simulation
area = [0, vshape[1]*dx, 0, vshape[0]*dz]
vmig = vmig/2. # half velocity due zero-offset section aproximation
# avoiding spatial alias, frequency of source should be smaller than this
#fc = 23.0 
dt = 0.00435758283082879
maxit = 500
snapshots = 1 # every 3 iterations plots one

# %%
# %cd fatiando
# Out:
# /home/andre/PycharmProjects/fatiando/fatiando

# %%
from fatiando.seismic import migration

# %%
rtmsimulation = migration.rtmscalar(vmig, area, dt, maxit, zeroffset, snapshot=1, padding=50)

# %%
import numpy as np
movie = np.zeros(((maxit/snapshots)+2, vshape[0], vshape[1]))
i = 0
for t, u  in rtmsimulation:
    movie[i] = u
    sys.stdout.write("\rprogressing .. %.1f%% time %.3f"%(100.0*float(t)/maxit, (dt*t)))
    sys.stdout.flush()
    i += 1
sys.stdout.write("\niteration %d"%(i))
# Out:
# progressing .. 0.0% time 0.000
# progressing .. 0.2% time 0.004
# progressing .. 0.4% time 0.009
# progressing .. 0.6% time 0.013
# progressing .. 0.8% time 0.017
# progressing .. 1.0% time 0.022
# progressing .. 1.2% time 0.026
# progressing .. 1.4% time 0.031
# progressing .. 1.6% time 0.035
# progressing .. 1.8% time 0.039
# progressing .. 2.0% time 0.044
# progressing .. 2.2% time 0.048
# progressing .. 2.4% time 0.052
# progressing .. 2.6% time 0.057
# progressing .. 2.8% time 0.061
# progressing .. 3.0% time 0.065
# progressing .. 3.2% time 0.070
# progressing .. 3.4% time 0.074
# progressing .. 3.6% time 0.078
# progressing .. 3.8% time 0.083
# progressing .. 4.0% time 0.087
# progressing .. 4.2% time 0.092
# progressing .. 4.4% time 0.096
# progressing .. 4.6% time 0.100
# progressing .. 4.8% time 0.105
# progressing .. 5.0% time 0.109
# progressing .. 5.2% time 0.113
# progressing .. 5.4% time 0.118
# progressing .. 5.6% time 0.122
# progressing .. 5.8% time 0.126
# ...

# %%
print zeroffset.shape
print vmig.shape
# Out:
# (500, 100)
# (120, 100)

# %%
# there is no need for that much of depth

def pstep(iter):
    figure(figsize=(10,15))
    tmv = movie[iter][::-1]    
    imshow(tmv, cmap=mpl.cm.gray_r, vmin=-.005, vmax=.005, extent=area, origin='lower')

pstep(300)
pstep(320)
pstep(340)
pstep(360)
pstep(370)
pstep(380)
pstep(400)
pstep(420)
pstep(470)
pstep(490)
pstep(500)

# %% [markdown]
# ### The reverse code seams to be working, must make commom kernel tests ###
#
# ### like hyperbola or spike migration with constant velocity ###

# %%
plot(zeroffset[:, 50], 'b+')

# %%
# %cd /home/andre/PycharmProjects/fatiando
import numpy as np
cmps_stacked = np.load('cmp_stacked.npy')
print cmps_stacked.shape

# 3225 to 16575 by 50
# 50 dx becomes aproximatelly 
icmps = [ 64+i for i in xrange(268)]
v2mig = data[:, icmps]
v2shape = v2mig.shape
print v2shape
# Basic parameters for zero-offset reverse modeling
dx = 50. # spacing between ~ pseudo cmps
dz = 25. # still the same from simulation
area = [0, v2shape[1]*50, 0, v2shape[0]*dz]
v2mig = v2mig/2. # half velocity due zero-offset section aproximation
# avoiding spatial alias, frequency of source should be smaller than this
#fc = 23.0 
dt = 0.00435758283082879
maxit = 917
snapshots = 1 # every 3 iterations plots one
# %cd fatiando
from fatiando.seismic import migration
rtmsimulation = migration.rtmscalar(v2mig, area, dt, maxit, cmps_stacked, snapshot=1, padding=50)
import numpy as np
movie = np.zeros(((maxit/snapshots)+2, v2shape[0], v2shape[1]))
i = 0
for t, u  in rtmsimulation:
    movie[i] = u
    sys.stdout.write("\rprogressing .. %.1f%% time %.3f"%(100.0*float(t)/maxit, (dt*t)))
    sys.stdout.flush()
    i += 1
sys.stdout.write("\niteration %d"%(i))
# Out:
# /home/andre/PycharmProjects/fatiando
# (917, 268)
# (160, 268)
# /home/andre/PycharmProjects/fatiando/fatiando
# progressing .. 0.0% time 0.000
# progressing .. 0.1% time 0.004
# progressing .. 0.2% time 0.009
# progressing .. 0.3% time 0.013
# progressing .. 0.4% time 0.017
# progressing .. 0.5% time 0.022
# progressing .. 0.7% time 0.026
# progressing .. 0.8% time 0.031
# progressing .. 0.9% time 0.035
# progressing .. 1.0% time 0.039
# progressing .. 1.1% time 0.044
# progressing .. 1.2% time 0.048
# progressing .. 1.3% time 0.052
# progressing .. 1.4% time 0.057
# progressing .. 1.5% time 0.061
# progressing .. 1.6% time 0.065
# progressing .. 1.7% time 0.070
# progressing .. 1.9% time 0.074
# progressing .. 2.0% time 0.078
# progressing .. 2.1% time 0.083
# progressing .. 2.2% time 0.087
# progressing .. 2.3% time 0.092
# progressing .. 2.4% time 0.096
# progressing .. 2.5% time 0.100
# progressing .. 2.6% time 0.105
# progressing .. 2.7% time 0.109
# ...

# %%
# there is no need for that much of depth

def pstep(iter):
    figure(figsize=(10,15))
    tmv = movie[iter][::-1]    
    imshow(tmv, cmap=mpl.cm.gray_r, vmin=-.1, vmax=.1, extent=area, origin='lower')

pstep(300)
pstep(320)
pstep(340)
pstep(360)
pstep(370)
pstep(380)
pstep(400)
pstep(420)
pstep(470)
pstep(490)
pstep(500)

# %%
figure(figsize(13,15))
imshow(cmps_stacked, cmap=mpl.cm.gray_r, vmin=-.5, vmax=.5, extent=area)
