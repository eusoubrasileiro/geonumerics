# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plot(rand(100))

# %%
from scipy import signal
b, a = signal.butter(8, (0.125, 0.25), btype='bandpass')
s = rand(100)
s = signal.detrend(s)
plot(s)
sf = signal.filtfilt(b, a, s)
plot(sf)
